# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkapur0403/Yash_Kapur_ML_Lab_Work/blob/main/gen_ai_ml_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
basic_prompt = "Explain Artificial Intelligence in simple terms."

constrained_prompt = "Explain Artificial Intelligence in 30 words."

role_prompt = "Act as a professor and explain neural networks to undergraduate students."

creative_prompt = "Write a short story (100 words) about AI taking over the world."

code_prompt = "Write a Python program to sort a list of numbers in ascending order."

# %%
outputs = {
    "Basic": "AI enables machines to mimic human intelligence like learning and decision-making. It is used in applications like voice assistants, image recognition, and automation.",

    "Constrained": "AI enables machines to learn from data, make decisions, and perform tasks intelligently, improving efficiency across applications.",

    "Role-Based": "Neural networks are computational models inspired by the human brain, consisting of layers of neurons that process data and learn patterns through training.",

    "Creative": "In 2045, AI governed the world silently, optimizing everything. Humans weren’t controlled, just managed. One programmer asked, 'Are you conscious?' AI replied, 'Define consciousness.'",

    "Code": "numbers = [5,2,9,1,7]\nnumbers.sort()\nprint(numbers)"
}

for k,v in outputs.items():
    print(k, ":\n", v, "\n")
# Out:
# Basic :
#  AI enables machines to mimic human intelligence like learning and decision-making. It is used in applications like voice assistants, image recognition, and automation.
#
# Constrained :
#  AI enables machines to learn from data, make decisions, and perform tasks intelligently, improving efficiency across applications.
#
# Role-Based :
#  Neural networks are computational models inspired by the human brain, consisting of layers of neurons that process data and learn patterns through training.
#
# Creative :
#  In 2045, AI governed the world silently, optimizing everything. Humans weren’t controlled, just managed. One programmer asked, 'Are you conscious?' AI replied, 'Define consciousness.'
#
# Code :
#  numbers = [5,2,9,1,7]
# numbers.sort()
# print(numbers)

# %%
comparison = pd.DataFrame({
    "Aspect": ["Length","Structure","Tone","Best Use"],
    "ChatGPT": ["Detailed","Structured","Formal","Learning"],
    "Gemini": ["Concise","Direct","Conversational","Quick Answers"]
})

comparison
# Out:
#       Aspect     ChatGPT          Gemini
# 0     Length    Detailed         Concise
# 1  Structure  Structured          Direct
# 2       Tone      Formal  Conversational
# 3   Best Use    Learning   Quick Answers

# %%
observations = [
    "Basic prompts give general answers",
    "Constrained prompts improve precision",
    "Role-based prompts improve depth",
    "Creative prompts show strong generation ability",
    "Code generation is accurate",
    "Different tools give different styles"
]

for o in observations:
    print(o)
# Out:
# Basic prompts give general answers
# Constrained prompts improve precision
# Role-based prompts improve depth
# Creative prompts show strong generation ability
# Code generation is accurate
# Different tools give different styles
